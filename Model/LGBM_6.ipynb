# %%
from datetime import date, timedelta
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error
import matplotlib as plp
import lightgbm as lgb

# %%
df_train = pd.read_csv(
    '../Data/train_set.csv', usecols=[1, 2, 3, 4, 5],
    converters={'unit_sales': lambda u: np.log1p(
        float(u)) if float(u) > 0 else 0},
    parse_dates=["date"],dtype={'onpromotion': bool}
)

# %%
df_test = pd.read_csv(
    "../Data/test.csv", usecols=[0, 1, 2, 3, 4],
    dtype={'onpromotion': bool},
    parse_dates=["date"]  # , date_parser=parser
).set_index(
    ['store_nbr', 'item_nbr', 'date']
)

# %%
items = pd.read_csv(
    "../Data/items.csv",
).set_index("item_nbr") #In order to give weight to item perishable

# %%
promo_train = df_train.set_index(
    ["store_nbr", "item_nbr", "date"])[["onpromotion"]].unstack(
        level=-1).fillna(False)

# %%
promo_train.columns = promo_train.columns.get_level_values(1)

# %%
promo_test = df_test[["onpromotion"]].unstack(level=-1).fillna(False)
promo_test.columns = promo_test.columns.get_level_values(1)

# %%
promo_test = promo_test.reindex(promo_train.index).fillna(False)
promo_2017 = pd.concat([promo_train, promo_test], axis=1)
del promo_test, promo_train

# %%
df_train = df_train.set_index(
    ["store_nbr", "item_nbr", "date"])[["unit_sales"]].unstack(
        level=-1).fillna(0)
df_train.columns = df_train.columns.get_level_values(1)

# %%
items = items.reindex(df_train.index.get_level_values(1))

# %%
def get_timespan(df, dt, minus, periods):
    return df[
        pd.date_range(dt - timedelta(days=minus), periods=periods)
    ]

# %%
def prepare_dataset(t2017, is_train=True):
    X = pd.DataFrame({
        "mean_3_2017": get_timespan(df_train, t2017, 3, 3).mean(axis=1).values,
        "mean_7_2017": get_timespan(df_train, t2017, 7, 7).mean(axis=1).values,
        "mean_14_2017": get_timespan(df_train, t2017, 14, 14).mean(axis=1).values,
        "mean_16_2017": get_timespan(df_train, t2017, 16, 16).mean(axis=1).values,
        "median_3_2017": get_timespan(df_train, t2017, 3, 3).median(axis=1).values,
        "median_7_2017": get_timespan(df_train, t2017, 7, 7).median(axis=1).values,
        "median_14_2017": get_timespan(df_train, t2017, 14, 14).median(axis=1).values,
        "median_16_2017": get_timespan(df_train, t2017, 16, 16).median(axis=1).values,
        "std_3_2017": get_timespan(df_train, t2017, 3, 3).std(axis=1).values,
        "std_7_2017": get_timespan(df_train, t2017, 7, 7).std(axis=1).values,
        "std_14_2017": get_timespan(df_train, t2017, 14, 14).std(axis=1).values,
        "std_16_2017": get_timespan(df_train, t2017, 16, 16).std(axis=1).values,
        "promo_14_2017": get_timespan(promo_2017, t2017, 14, 14).sum(axis=1).values  
    })
    for i in range(16):
        X["promo_{}".format(i)] = promo_2017[t2017 + timedelta(days=i)].values.astype(np.uint8)
    if is_train:
        y = df_train[
            pd.date_range(t2017, periods=16)
        ].values
        return X, y
    return X

# %%
print("Preparing dataset...")
t2017 = date(2017, 5, 16)
X_l, y_l = [], []
for i in range(9):
    delta = timedelta(days=7 * i)
    X_tmp, y_tmp = prepare_dataset(t2017 + delta)
    X_l.append(X_tmp)
    y_l.append(y_tmp)
X_train = pd.concat(X_l, axis=0)
y_train = np.concatenate(y_l, axis=0)
del X_l, y_l
# Out:
# Preparing dataset...

# %%
X_val, y_val = prepare_dataset(date(2017, 7, 23))

# %%
X_test = prepare_dataset(date(2017, 8, 16), is_train=False)

# %%
print("Training and predicting models...")
params = {
    'num_leaves': 80,
    'objective': 'regression',
    'min_data_in_leaf': 200,
    'learning_rate': 0.02,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.7,
    'bagging_freq': 1,
    'metric': 'l2',
    'num_threads': 16
}

MAX_ROUNDS = 5000
val_pred = []
test_pred = []
cate_vars = []
for i in range(16):
    print("=" * 50)
    print("Step %d" % (i+1))
    print("=" * 50)
    dtrain = lgb.Dataset(
        X_train, label=y_train[:, i],
        categorical_feature=cate_vars,
        weight=pd.concat([items["perishable"]] * 9) * 0.25 + 1
    )
    
    dval = lgb.Dataset(
        X_val, label=y_val[:, i], reference=dtrain,
        categorical_feature=cate_vars,
        weight=items["perishable"] * 0.25 + 1
    )
    
    bst = lgb.train(
        params, dtrain, num_boost_round=MAX_ROUNDS,
        valid_sets=[dtrain, dval], early_stopping_rounds=50, verbose_eval=50
    )
    
    print("\n".join(("%s: %.2f" % x) for x in sorted(
        zip(X_train.columns, bst.feature_importance("gain")),
        key=lambda x: x[1], reverse=True
    )))
    val_pred.append(bst.predict(
        X_val, num_iteration=bst.best_iteration or MAX_ROUNDS))
    test_pred.append(bst.predict(
        X_test, num_iteration=bst.best_iteration or MAX_ROUNDS))

print("Validation mse:", mean_squared_error(
    y_val, np.array(val_pred).transpose()))
# Out:
# Training and predicting models...
# ==================================================
# Step 1
# ==================================================
# /Users/arkarmin/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py:1186: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.445759	valid_1's l2: 0.573596
# [100]	training's l2: 0.353489	valid_1's l2: 0.454515
# [150]	training's l2: 0.338403	valid_1's l2: 0.429042
# [200]	training's l2: 0.334211	valid_1's l2: 0.421773
# [250]	training's l2: 0.332217	valid_1's l2: 0.418703
# [300]	training's l2: 0.330931	valid_1's l2: 0.416977
# [350]	training's l2: 0.329947	valid_1's l2: 0.41615
# [400]	training's l2: 0.329279	valid_1's l2: 0.415644
# [450]	training's l2: 0.328646	valid_1's l2: 0.415435
# [500]	training's l2: 0.328112	valid_1's l2: 0.415194
# [550]	training's l2: 0.327617	valid_1's l2: 0.414991
# [600]	training's l2: 0.32715	valid_1's l2: 0.4149
# [650]	training's l2: 0.326708	valid_1's l2: 0.41477
# [700]	training's l2: 0.326288	valid_1's l2: 0.414606
# [750]	training's l2: 0.325877	valid_1's l2: 0.414494
# [800]	training's l2: 0.325478	valid_1's l2: 0.414442
# [850]	training's l2: 0.325101	valid_1's l2: 0.414426
# [900]	training's l2: 0.324723	valid_1's l2: 0.414407
# Early stopping, best iteration is:
# [880]	training's l2: 0.324869	valid_1's l2: 0.414374
# mean_7_2017: 9237786.81
# mean_14_2017: 6539579.61
# mean_16_2017: 2620925.25
# mean_3_2017: 1159348.46
# promo_0: 458446.91
# promo_14_2017: 271853.39
# median_16_2017: 171417.86
# std_7_2017: 79192.61
# std_3_2017: 71787.96
# std_14_2017: 67984.27
# median_7_2017: 66216.67
# std_16_2017: 63258.53
# median_3_2017: 40207.49
# promo_1: 36936.15
# promo_7: 31752.31
# median_14_2017: 29550.00
# promo_14: 17931.48
# promo_4: 17114.03
# promo_5: 11404.77
# promo_15: 10393.55
# promo_8: 8840.82
# promo_13: 7369.96
# promo_10: 7166.55
# promo_3: 6292.13
# promo_2: 5763.12
# promo_12: 5423.50
# promo_6: 4219.05
# promo_11: 4018.32
# promo_9: 3640.77
# ==================================================
# Step 2
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.448919	valid_1's l2: 0.484075
# [100]	training's l2: 0.352226	valid_1's l2: 0.390989
# [150]	training's l2: 0.336253	valid_1's l2: 0.375683
# [200]	training's l2: 0.332341	valid_1's l2: 0.372488
# [250]	training's l2: 0.330519	valid_1's l2: 0.371001
# [300]	training's l2: 0.329288	valid_1's l2: 0.370074
# [350]	training's l2: 0.328405	valid_1's l2: 0.369522
# [400]	training's l2: 0.327714	valid_1's l2: 0.369226
# [450]	training's l2: 0.327137	valid_1's l2: 0.369042
# [500]	training's l2: 0.326646	valid_1's l2: 0.368885
# [550]	training's l2: 0.32618	valid_1's l2: 0.368734
# [600]	training's l2: 0.325738	valid_1's l2: 0.368652
# [650]	training's l2: 0.325316	valid_1's l2: 0.36857
# [700]	training's l2: 0.324925	valid_1's l2: 0.368493
# [750]	training's l2: 0.324526	valid_1's l2: 0.368391
# [800]	training's l2: 0.324155	valid_1's l2: 0.368328
# [850]	training's l2: 0.32381	valid_1's l2: 0.368307
# [900]	training's l2: 0.323456	valid_1's l2: 0.368251
# [950]	training's l2: 0.323113	valid_1's l2: 0.368209
# Early stopping, best iteration is:
# [937]	training's l2: 0.323205	valid_1's l2: 0.368199
# mean_14_2017: 10885257.12
# mean_7_2017: 6883926.65
# mean_16_2017: 1367788.29
# promo_1: 744203.71
# median_7_2017: 412399.53
# median_14_2017: 316736.66
# median_16_2017: 297720.61
# promo_14_2017: 283632.69
# mean_3_2017: 142222.73
# std_14_2017: 97716.79
# promo_8: 97605.03
# std_16_2017: 95138.34
# std_7_2017: 82890.45
# promo_15: 42738.70
# std_3_2017: 41930.86
# promo_0: 34017.66
# median_3_2017: 33918.57
# promo_10: 20166.50
# promo_14: 18916.33
# promo_4: 11728.65
# promo_12: 9428.55
# promo_5: 8816.79
# promo_3: 8581.65
# promo_2: 7359.40
# promo_7: 4472.31
# promo_13: 3648.93
# promo_6: 2902.60
# promo_11: 2753.17
# promo_9: 1994.29
# ==================================================
# Step 3
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.447818	valid_1's l2: 0.469856
# [100]	training's l2: 0.368781	valid_1's l2: 0.378742
# [150]	training's l2: 0.355924	valid_1's l2: 0.36176
# [200]	training's l2: 0.352565	valid_1's l2: 0.357137
# [250]	training's l2: 0.350919	valid_1's l2: 0.355289
# [300]	training's l2: 0.349696	valid_1's l2: 0.354245
# [350]	training's l2: 0.348817	valid_1's l2: 0.353722
# [400]	training's l2: 0.348148	valid_1's l2: 0.353465
# [450]	training's l2: 0.347594	valid_1's l2: 0.353299
# [500]	training's l2: 0.347072	valid_1's l2: 0.353201
# [550]	training's l2: 0.346583	valid_1's l2: 0.353079
# [600]	training's l2: 0.346129	valid_1's l2: 0.35301
# [650]	training's l2: 0.345687	valid_1's l2: 0.352897
# [700]	training's l2: 0.345252	valid_1's l2: 0.352851
# [750]	training's l2: 0.344843	valid_1's l2: 0.352816
# [800]	training's l2: 0.344455	valid_1's l2: 0.35274
# [850]	training's l2: 0.344072	valid_1's l2: 0.352715
# [900]	training's l2: 0.343704	valid_1's l2: 0.352685
# [950]	training's l2: 0.343334	valid_1's l2: 0.352658
# [1000]	training's l2: 0.342984	valid_1's l2: 0.352643
# [1050]	training's l2: 0.34263	valid_1's l2: 0.352627
# Early stopping, best iteration is:
# [1016]	training's l2: 0.342873	valid_1's l2: 0.352622
# mean_14_2017: 10400537.39
# mean_7_2017: 4361531.43
# mean_16_2017: 1603875.44
# promo_2: 382453.68
# median_7_2017: 351367.86
# promo_14_2017: 228008.20
# median_14_2017: 193513.20
# mean_3_2017: 95115.42
# std_16_2017: 86914.98
# median_16_2017: 77948.95
# std_14_2017: 66888.78
# std_7_2017: 51486.67
# promo_1: 40495.82
# std_3_2017: 39415.29
# promo_4: 35445.09
# median_3_2017: 33309.58
# promo_3: 25910.73
# promo_5: 25022.47
# promo_6: 15783.89
# promo_0: 14455.57
# promo_7: 11574.87
# promo_8: 10731.10
# promo_15: 9024.61
# promo_9: 8759.03
# promo_14: 5178.33
# promo_10: 4659.02
# promo_12: 3322.40
# promo_11: 2040.13
# promo_13: 1702.85
# ==================================================
# Step 4
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.483519	valid_1's l2: 0.443416
# [100]	training's l2: 0.388158	valid_1's l2: 0.354698
# [150]	training's l2: 0.371971	valid_1's l2: 0.341667
# [200]	training's l2: 0.367801	valid_1's l2: 0.33939
# [250]	training's l2: 0.365916	valid_1's l2: 0.338749
# [300]	training's l2: 0.364586	valid_1's l2: 0.33833
# [350]	training's l2: 0.363648	valid_1's l2: 0.338211
# [400]	training's l2: 0.362914	valid_1's l2: 0.338157
# Early stopping, best iteration is:
# [399]	training's l2: 0.362925	valid_1's l2: 0.338152
# mean_14_2017: 12687902.32
# mean_7_2017: 5111882.14
# mean_16_2017: 1127790.92
# promo_3: 631258.71
# median_7_2017: 403766.97
# promo_14_2017: 292855.75
# median_14_2017: 285161.45
# std_16_2017: 136195.50
# std_14_2017: 124035.26
# median_16_2017: 77645.08
# promo_10: 70542.54
# mean_3_2017: 67585.20
# std_7_2017: 56665.08
# promo_1: 35830.45
# promo_4: 33866.21
# promo_6: 27677.39
# promo_5: 27596.08
# median_3_2017: 21560.94
# promo_8: 20813.39
# promo_0: 20299.18
# std_3_2017: 17789.92
# promo_15: 17052.81
# promo_7: 14249.70
# promo_2: 12662.30
# promo_12: 10776.42
# promo_11: 10369.06
# promo_14: 9460.84
# promo_13: 6068.08
# promo_9: 5511.32
# ==================================================
# Step 5
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.51338	valid_1's l2: 0.496888
# [100]	training's l2: 0.407493	valid_1's l2: 0.436231
# [150]	training's l2: 0.389878	valid_1's l2: 0.433023
# Early stopping, best iteration is:
# [134]	training's l2: 0.392826	valid_1's l2: 0.432865
# mean_16_2017: 10918366.32
# mean_14_2017: 8877467.94
# mean_7_2017: 1299989.74
# mean_3_2017: 1041085.37
# promo_4: 366011.78
# median_3_2017: 234926.29
# promo_14_2017: 201781.08
# median_16_2017: 177692.14
# std_16_2017: 122296.58
# std_14_2017: 65415.67
# median_14_2017: 45195.99
# promo_6: 40245.07
# promo_5: 37466.91
# promo_3: 37219.61
# promo_8: 24333.95
# std_7_2017: 20643.90
# promo_7: 18126.51
# promo_1: 12687.50
# promo_0: 10810.35
# std_3_2017: 10555.23
# median_7_2017: 8235.36
# promo_15: 7079.29
# promo_9: 6541.96
# promo_2: 4847.85
# promo_10: 4427.92
# promo_11: 2860.89
# promo_14: 1624.03
# promo_13: 487.42
# promo_12: 203.48
# ==================================================
# Step 6
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.544431	valid_1's l2: 0.508492
# [100]	training's l2: 0.432076	valid_1's l2: 0.42364
# [150]	training's l2: 0.413001	valid_1's l2: 0.412427
# [200]	training's l2: 0.407658	valid_1's l2: 0.410134
# [250]	training's l2: 0.404669	valid_1's l2: 0.408956
# [300]	training's l2: 0.402634	valid_1's l2: 0.408256
# [350]	training's l2: 0.401102	valid_1's l2: 0.407845
# [400]	training's l2: 0.400024	valid_1's l2: 0.407619
# [450]	training's l2: 0.399132	valid_1's l2: 0.4074
# [500]	training's l2: 0.398346	valid_1's l2: 0.407269
# [550]	training's l2: 0.397672	valid_1's l2: 0.407192
# [600]	training's l2: 0.397024	valid_1's l2: 0.407177
# [650]	training's l2: 0.396424	valid_1's l2: 0.407098
# [700]	training's l2: 0.395856	valid_1's l2: 0.407074
# [750]	training's l2: 0.395316	valid_1's l2: 0.406948
# Early stopping, best iteration is:
# [742]	training's l2: 0.395404	valid_1's l2: 0.406935
# mean_16_2017: 17537940.44
# mean_3_2017: 3206783.99
# mean_14_2017: 2461606.31
# median_16_2017: 918520.13
# promo_5: 436543.57
# median_3_2017: 243097.77
# promo_14_2017: 216728.48
# std_16_2017: 169558.09
# mean_7_2017: 132162.44
# promo_4: 47667.13
# std_3_2017: 47211.26
# promo_8: 46118.90
# std_14_2017: 44971.33
# promo_6: 44936.49
# promo_7: 41087.80
# std_7_2017: 31963.00
# promo_1: 28293.20
# promo_3: 25561.63
# median_14_2017: 24797.77
# median_7_2017: 21665.42
# promo_2: 20766.75
# promo_12: 17961.20
# promo_15: 17698.76
# promo_0: 15609.43
# promo_10: 12331.28
# promo_9: 9927.27
# promo_14: 8735.54
# promo_11: 8225.32
# promo_13: 6668.03
# ==================================================
# Step 7
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.4944	valid_1's l2: 0.575447
# [100]	training's l2: 0.40394	valid_1's l2: 0.466033
# [150]	training's l2: 0.388682	valid_1's l2: 0.443834
# [200]	training's l2: 0.384445	valid_1's l2: 0.437254
# [250]	training's l2: 0.382229	valid_1's l2: 0.434554
# [300]	training's l2: 0.380776	valid_1's l2: 0.433274
# [350]	training's l2: 0.379685	valid_1's l2: 0.432629
# [400]	training's l2: 0.378863	valid_1's l2: 0.432332
# [450]	training's l2: 0.378228	valid_1's l2: 0.432103
# [500]	training's l2: 0.377582	valid_1's l2: 0.432013
# [550]	training's l2: 0.377034	valid_1's l2: 0.431978
# [600]	training's l2: 0.376534	valid_1's l2: 0.431896
# [650]	training's l2: 0.376046	valid_1's l2: 0.431888
# [700]	training's l2: 0.375576	valid_1's l2: 0.431802
# [750]	training's l2: 0.375099	valid_1's l2: 0.431815
# Early stopping, best iteration is:
# [701]	training's l2: 0.375564	valid_1's l2: 0.431793
# mean_16_2017: 12134660.45
# mean_14_2017: 3374296.83
# mean_7_2017: 2883604.77
# mean_3_2017: 561783.10
# promo_6: 447144.51
# median_16_2017: 289313.77
# promo_14_2017: 230909.71
# median_7_2017: 106453.80
# std_16_2017: 104679.81
# promo_4: 69533.85
# promo_8: 55480.41
# promo_7: 55454.16
# std_14_2017: 45378.68
# std_3_2017: 32481.66
# promo_5: 30619.62
# std_7_2017: 30606.99
# median_3_2017: 28830.64
# median_14_2017: 27016.50
# promo_1: 20984.24
# promo_3: 19616.16
# promo_0: 16636.13
# promo_15: 16552.51
# promo_10: 13252.01
# promo_2: 12147.29
# promo_9: 9548.69
# promo_14: 8437.90
# promo_12: 8417.57
# promo_13: 7837.33
# promo_11: 6245.39
# ==================================================
# Step 8
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.479551	valid_1's l2: 0.662399
# [100]	training's l2: 0.391815	valid_1's l2: 0.542103
# [150]	training's l2: 0.376723	valid_1's l2: 0.51438
# [200]	training's l2: 0.3724	valid_1's l2: 0.505309
# [250]	training's l2: 0.370246	valid_1's l2: 0.501398
# [300]	training's l2: 0.36878	valid_1's l2: 0.499433
# [350]	training's l2: 0.367678	valid_1's l2: 0.498283
# [400]	training's l2: 0.366949	valid_1's l2: 0.497833
# [450]	training's l2: 0.366278	valid_1's l2: 0.497467
# [500]	training's l2: 0.365689	valid_1's l2: 0.497162
# [550]	training's l2: 0.365178	valid_1's l2: 0.496979
# [600]	training's l2: 0.364676	valid_1's l2: 0.496875
# [650]	training's l2: 0.36421	valid_1's l2: 0.496669
# [700]	training's l2: 0.363779	valid_1's l2: 0.49645
# [750]	training's l2: 0.363339	valid_1's l2: 0.49636
# [800]	training's l2: 0.362928	valid_1's l2: 0.496265
# [850]	training's l2: 0.362522	valid_1's l2: 0.496183
# [900]	training's l2: 0.362114	valid_1's l2: 0.496147
# [950]	training's l2: 0.361716	valid_1's l2: 0.496004
# [1000]	training's l2: 0.361356	valid_1's l2: 0.495962
# [1050]	training's l2: 0.360978	valid_1's l2: 0.495883
# [1100]	training's l2: 0.360601	valid_1's l2: 0.495724
# [1150]	training's l2: 0.360253	valid_1's l2: 0.495705
# [1200]	training's l2: 0.359913	valid_1's l2: 0.495727
# Early stopping, best iteration is:
# [1165]	training's l2: 0.360154	valid_1's l2: 0.495685
# mean_14_2017: 8495564.12
# mean_16_2017: 5864273.33
# mean_7_2017: 3176588.00
# promo_7: 736520.57
# median_16_2017: 335383.23
# promo_14_2017: 227373.82
# median_7_2017: 143299.03
# std_16_2017: 117450.12
# mean_3_2017: 105456.87
# promo_0: 103768.23
# promo_8: 85844.61
# std_14_2017: 71319.80
# promo_4: 70718.60
# promo_14: 70577.32
# std_7_2017: 47625.94
# std_3_2017: 41703.63
# median_14_2017: 38233.22
# promo_6: 37207.90
# median_3_2017: 33651.78
# promo_1: 29238.58
# promo_5: 26023.78
# promo_15: 21774.74
# promo_3: 17323.54
# promo_10: 16444.61
# promo_2: 10459.11
# promo_12: 8545.81
# promo_9: 6955.62
# promo_11: 5515.25
# promo_13: 5075.71
# ==================================================
# Step 9
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.474272	valid_1's l2: 0.547553
# [100]	training's l2: 0.38229	valid_1's l2: 0.449102
# [150]	training's l2: 0.366688	valid_1's l2: 0.429738
# [200]	training's l2: 0.362734	valid_1's l2: 0.424003
# [250]	training's l2: 0.360713	valid_1's l2: 0.42151
# [300]	training's l2: 0.35948	valid_1's l2: 0.420188
# [350]	training's l2: 0.358474	valid_1's l2: 0.41952
# [400]	training's l2: 0.357782	valid_1's l2: 0.419098
# [450]	training's l2: 0.357179	valid_1's l2: 0.418843
# [500]	training's l2: 0.35658	valid_1's l2: 0.41861
# [550]	training's l2: 0.356102	valid_1's l2: 0.418413
# [600]	training's l2: 0.35563	valid_1's l2: 0.418224
# [650]	training's l2: 0.35518	valid_1's l2: 0.418093
# [700]	training's l2: 0.354741	valid_1's l2: 0.417983
# [750]	training's l2: 0.354333	valid_1's l2: 0.41783
# [800]	training's l2: 0.353958	valid_1's l2: 0.417727
# [850]	training's l2: 0.353559	valid_1's l2: 0.41761
# [900]	training's l2: 0.353165	valid_1's l2: 0.417581
# [950]	training's l2: 0.352798	valid_1's l2: 0.417493
# [1000]	training's l2: 0.35245	valid_1's l2: 0.41746
# [1050]	training's l2: 0.352086	valid_1's l2: 0.417416
# [1100]	training's l2: 0.351741	valid_1's l2: 0.417321
# [1150]	training's l2: 0.351419	valid_1's l2: 0.417307
# [1200]	training's l2: 0.351097	valid_1's l2: 0.417288
# [1250]	training's l2: 0.350779	valid_1's l2: 0.41726
# [1300]	training's l2: 0.350466	valid_1's l2: 0.417267
# Early stopping, best iteration is:
# [1256]	training's l2: 0.350743	valid_1's l2: 0.417258
# mean_14_2017: 10151412.60
# mean_16_2017: 4081268.57
# mean_7_2017: 3422521.81
# promo_8: 1080801.75
# median_14_2017: 480811.36
# median_7_2017: 395178.93
# median_16_2017: 327983.46
# promo_14_2017: 237980.35
# promo_1: 207691.10
# std_16_2017: 140849.14
# std_14_2017: 100498.46
# promo_15: 99795.62
# mean_3_2017: 67891.72
# std_7_2017: 57129.64
# promo_4: 38568.45
# std_3_2017: 38532.10
# median_3_2017: 36312.59
# promo_7: 29744.26
# promo_6: 26477.90
# promo_10: 24329.68
# promo_3: 17420.41
# promo_0: 16858.35
# promo_5: 16080.59
# promo_9: 10541.83
# promo_14: 10462.54
# promo_12: 7517.84
# promo_2: 6526.04
# promo_11: 4251.65
# promo_13: 3393.80
# ==================================================
# Step 10
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.470742	valid_1's l2: 0.64825
# [100]	training's l2: 0.394213	valid_1's l2: 0.53823
# [150]	training's l2: 0.380931	valid_1's l2: 0.51235
# [200]	training's l2: 0.377132	valid_1's l2: 0.503643
# [250]	training's l2: 0.375112	valid_1's l2: 0.49944
# [300]	training's l2: 0.37371	valid_1's l2: 0.496945
# [350]	training's l2: 0.372709	valid_1's l2: 0.495688
# [400]	training's l2: 0.371908	valid_1's l2: 0.494868
# [450]	training's l2: 0.371294	valid_1's l2: 0.494398
# [500]	training's l2: 0.370737	valid_1's l2: 0.493975
# [550]	training's l2: 0.370219	valid_1's l2: 0.493623
# [600]	training's l2: 0.369717	valid_1's l2: 0.49334
# [650]	training's l2: 0.369233	valid_1's l2: 0.493024
# [700]	training's l2: 0.368774	valid_1's l2: 0.492815
# [750]	training's l2: 0.368358	valid_1's l2: 0.492716
# [800]	training's l2: 0.367947	valid_1's l2: 0.492524
# [850]	training's l2: 0.367555	valid_1's l2: 0.492347
# [900]	training's l2: 0.367168	valid_1's l2: 0.492213
# [950]	training's l2: 0.366784	valid_1's l2: 0.492113
# [1000]	training's l2: 0.366417	valid_1's l2: 0.492076
# [1050]	training's l2: 0.366068	valid_1's l2: 0.492025
# [1100]	training's l2: 0.365698	valid_1's l2: 0.491862
# [1150]	training's l2: 0.365338	valid_1's l2: 0.49181
# [1200]	training's l2: 0.364992	valid_1's l2: 0.491761
# [1250]	training's l2: 0.364649	valid_1's l2: 0.491703
# Early stopping, best iteration is:
# [1225]	training's l2: 0.364818	valid_1's l2: 0.491665
# mean_14_2017: 7850626.34
# mean_16_2017: 5358190.27
# mean_7_2017: 2173634.59
# promo_9: 590428.79
# median_7_2017: 422740.65
# median_16_2017: 289445.50
# promo_14_2017: 266358.55
# std_16_2017: 119212.09
# median_14_2017: 106918.19
# std_14_2017: 68373.14
# mean_3_2017: 67445.58
# promo_8: 65356.50
# std_7_2017: 49320.10
# std_3_2017: 42262.10
# promo_10: 39933.50
# promo_11: 37293.59
# median_3_2017: 35921.50
# promo_12: 24779.61
# promo_1: 24720.24
# promo_4: 18866.13
# promo_13: 18195.14
# promo_15: 17869.01
# promo_0: 17206.57
# promo_14: 15745.94
# promo_7: 15417.33
# promo_2: 11525.04
# promo_5: 10089.77
# promo_3: 9688.74
# promo_6: 7417.11
# ==================================================
# Step 11
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.505692	valid_1's l2: 0.549832
# [100]	training's l2: 0.413661	valid_1's l2: 0.44445
# [150]	training's l2: 0.397687	valid_1's l2: 0.42515
# [200]	training's l2: 0.393488	valid_1's l2: 0.420312
# [250]	training's l2: 0.391373	valid_1's l2: 0.418446
# [300]	training's l2: 0.389895	valid_1's l2: 0.417492
# [350]	training's l2: 0.388785	valid_1's l2: 0.416925
# [400]	training's l2: 0.387985	valid_1's l2: 0.416538
# [450]	training's l2: 0.387284	valid_1's l2: 0.416223
# [500]	training's l2: 0.38667	valid_1's l2: 0.416015
# [550]	training's l2: 0.386097	valid_1's l2: 0.415857
# [600]	training's l2: 0.385569	valid_1's l2: 0.415737
# [650]	training's l2: 0.385071	valid_1's l2: 0.415655
# [700]	training's l2: 0.384587	valid_1's l2: 0.415584
# [750]	training's l2: 0.38414	valid_1's l2: 0.41556
# Early stopping, best iteration is:
# [731]	training's l2: 0.384308	valid_1's l2: 0.415538
# mean_16_2017: 8217769.56
# mean_14_2017: 7999112.32
# mean_7_2017: 1577596.50
# promo_10: 906828.21
# median_16_2017: 469109.99
# promo_14_2017: 325066.78
# median_7_2017: 302247.23
# std_16_2017: 207857.48
# median_14_2017: 191937.28
# promo_3: 99139.96
# std_14_2017: 92792.71
# promo_8: 64005.98
# mean_3_2017: 63153.60
# promo_11: 51967.25
# std_7_2017: 44320.32
# promo_15: 33887.36
# promo_13: 31604.18
# std_3_2017: 29154.28
# promo_12: 28285.56
# promo_0: 27310.65
# median_3_2017: 25521.50
# promo_14: 20082.08
# promo_1: 16822.72
# promo_7: 12161.51
# promo_9: 11858.13
# promo_2: 8233.80
# promo_4: 6464.72
# promo_5: 6270.54
# promo_6: 3315.80
# ==================================================
# Step 12
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.539478	valid_1's l2: 0.506389
# [100]	training's l2: 0.437503	valid_1's l2: 0.436075
# [150]	training's l2: 0.420046	valid_1's l2: 0.429441
# [200]	training's l2: 0.415312	valid_1's l2: 0.429433
# Early stopping, best iteration is:
# [153]	training's l2: 0.419608	valid_1's l2: 0.42933
# mean_16_2017: 16722106.15
# mean_14_2017: 2605280.32
# mean_7_2017: 877644.23
# promo_11: 578293.89
# mean_3_2017: 569631.65
# median_16_2017: 383851.31
# promo_14_2017: 245144.36
# median_3_2017: 226539.80
# std_16_2017: 157883.68
# promo_10: 63549.82
# promo_13: 47778.25
# promo_15: 41910.18
# promo_8: 37101.07
# promo_12: 33992.96
# std_14_2017: 25627.02
# promo_14: 20217.34
# promo_0: 15896.52
# std_3_2017: 14991.68
# promo_4: 11534.38
# std_7_2017: 10890.21
# median_7_2017: 10025.77
# promo_7: 7661.60
# promo_1: 6928.29
# promo_9: 5696.48
# promo_3: 5527.14
# median_14_2017: 2212.30
# promo_5: 1516.64
# promo_2: 1444.77
# promo_6: 939.72
# ==================================================
# Step 13
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.570614	valid_1's l2: 0.524163
# [100]	training's l2: 0.462205	valid_1's l2: 0.440746
# [150]	training's l2: 0.443095	valid_1's l2: 0.429327
# [200]	training's l2: 0.437333	valid_1's l2: 0.42689
# [250]	training's l2: 0.434176	valid_1's l2: 0.425506
# [300]	training's l2: 0.431777	valid_1's l2: 0.424323
# [350]	training's l2: 0.430093	valid_1's l2: 0.423691
# [400]	training's l2: 0.42877	valid_1's l2: 0.42317
# [450]	training's l2: 0.427818	valid_1's l2: 0.422799
# [500]	training's l2: 0.426938	valid_1's l2: 0.422476
# [550]	training's l2: 0.426207	valid_1's l2: 0.422172
# [600]	training's l2: 0.425508	valid_1's l2: 0.42197
# [650]	training's l2: 0.424824	valid_1's l2: 0.421826
# [700]	training's l2: 0.424206	valid_1's l2: 0.421711
# [750]	training's l2: 0.423631	valid_1's l2: 0.421687
# [800]	training's l2: 0.423076	valid_1's l2: 0.421592
# [850]	training's l2: 0.422552	valid_1's l2: 0.421516
# [900]	training's l2: 0.422034	valid_1's l2: 0.421388
# [950]	training's l2: 0.421521	valid_1's l2: 0.42141
# Early stopping, best iteration is:
# [912]	training's l2: 0.421919	valid_1's l2: 0.42137
# mean_16_2017: 18150350.52
# median_16_2017: 1862188.09
# mean_14_2017: 1591342.85
# mean_3_2017: 1222863.16
# promo_12: 603801.02
# promo_14_2017: 258786.47
# median_3_2017: 222043.12
# std_16_2017: 171554.48
# mean_7_2017: 109427.84
# promo_13: 78417.45
# promo_15: 77134.56
# promo_10: 53396.28
# promo_11: 52430.03
# promo_14: 50436.18
# std_14_2017: 50357.91
# promo_5: 48677.27
# std_3_2017: 48121.33
# promo_8: 42691.33
# std_7_2017: 37020.94
# median_14_2017: 34088.75
# median_7_2017: 26044.51
# promo_1: 18434.30
# promo_0: 17607.69
# promo_9: 17606.32
# promo_3: 14203.22
# promo_7: 13011.37
# promo_4: 6645.19
# promo_2: 6367.62
# promo_6: 4498.47
# ==================================================
# Step 14
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.514521	valid_1's l2: 0.58664
# [100]	training's l2: 0.426716	valid_1's l2: 0.485521
# [150]	training's l2: 0.411148	valid_1's l2: 0.465172
# [200]	training's l2: 0.406661	valid_1's l2: 0.459293
# [250]	training's l2: 0.404357	valid_1's l2: 0.456991
# [300]	training's l2: 0.402781	valid_1's l2: 0.455836
# [350]	training's l2: 0.401569	valid_1's l2: 0.455144
# [400]	training's l2: 0.400691	valid_1's l2: 0.454772
# [450]	training's l2: 0.399981	valid_1's l2: 0.454514
# [500]	training's l2: 0.399338	valid_1's l2: 0.454343
# [550]	training's l2: 0.398751	valid_1's l2: 0.454176
# [600]	training's l2: 0.39817	valid_1's l2: 0.45411
# [650]	training's l2: 0.397663	valid_1's l2: 0.453994
# [700]	training's l2: 0.397158	valid_1's l2: 0.453909
# [750]	training's l2: 0.39671	valid_1's l2: 0.453857
# Early stopping, best iteration is:
# [746]	training's l2: 0.396742	valid_1's l2: 0.453855
# mean_16_2017: 14631746.77
# mean_14_2017: 2261920.03
# median_16_2017: 745849.04
# promo_13: 619494.48
# mean_3_2017: 471396.14
# mean_7_2017: 386806.77
# promo_14_2017: 250015.52
# std_16_2017: 130269.62
# promo_15: 78408.96
# promo_11: 74857.63
# promo_14: 71218.99
# median_7_2017: 57172.08
# std_14_2017: 44487.24
# promo_10: 42789.79
# promo_12: 40578.23
# median_3_2017: 32943.65
# std_3_2017: 30214.65
# std_7_2017: 30170.67
# median_14_2017: 27198.92
# promo_8: 23728.46
# promo_0: 22346.92
# promo_1: 17829.55
# promo_3: 14546.48
# promo_9: 12420.53
# promo_7: 11612.50
# promo_6: 9854.58
# promo_4: 7177.53
# promo_2: 7089.81
# promo_5: 5950.97
# ==================================================
# Step 15
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.498566	valid_1's l2: 0.680521
# [100]	training's l2: 0.412169	valid_1's l2: 0.567439
# [150]	training's l2: 0.396568	valid_1's l2: 0.541704
# [200]	training's l2: 0.392049	valid_1's l2: 0.533455
# [250]	training's l2: 0.389742	valid_1's l2: 0.530076
# [300]	training's l2: 0.388099	valid_1's l2: 0.528415
# [350]	training's l2: 0.387025	valid_1's l2: 0.527407
# [400]	training's l2: 0.386255	valid_1's l2: 0.526882
# [450]	training's l2: 0.385539	valid_1's l2: 0.52652
# [500]	training's l2: 0.384914	valid_1's l2: 0.526289
# [550]	training's l2: 0.384359	valid_1's l2: 0.526109
# [600]	training's l2: 0.383827	valid_1's l2: 0.525965
# [650]	training's l2: 0.383364	valid_1's l2: 0.525846
# [700]	training's l2: 0.382924	valid_1's l2: 0.525774
# [750]	training's l2: 0.382469	valid_1's l2: 0.525673
# [800]	training's l2: 0.382029	valid_1's l2: 0.525565
# [850]	training's l2: 0.381608	valid_1's l2: 0.525481
# [900]	training's l2: 0.381188	valid_1's l2: 0.525404
# [950]	training's l2: 0.380782	valid_1's l2: 0.525333
# [1000]	training's l2: 0.380387	valid_1's l2: 0.525286
# [1050]	training's l2: 0.380024	valid_1's l2: 0.525227
# [1100]	training's l2: 0.379637	valid_1's l2: 0.525152
# [1150]	training's l2: 0.379259	valid_1's l2: 0.525194
# Early stopping, best iteration is:
# [1102]	training's l2: 0.379624	valid_1's l2: 0.525151
# mean_16_2017: 12672300.93
# mean_14_2017: 2115492.84
# mean_7_2017: 1789706.39
# promo_14: 867710.97
# median_16_2017: 514645.20
# promo_14_2017: 248914.91
# std_16_2017: 146364.18
# promo_15: 120813.04
# mean_3_2017: 116682.61
# median_7_2017: 112066.14
# promo_13: 83582.44
# promo_0: 72736.88
# promo_11: 71489.65
# promo_7: 67537.36
# std_14_2017: 61678.16
# promo_10: 40647.93
# median_3_2017: 38763.06
# std_7_2017: 38664.50
# median_14_2017: 38456.73
# std_3_2017: 36030.74
# promo_12: 35926.61
# promo_1: 35841.51
# promo_8: 25487.76
# promo_3: 18676.54
# promo_9: 10757.12
# promo_2: 8914.07
# promo_5: 7578.95
# promo_6: 5608.36
# promo_4: 5552.28
# ==================================================
# Step 16
# ==================================================
# Training until validation scores don't improve for 50 rounds.
# [50]	training's l2: 0.491439	valid_1's l2: 0.537273
# [100]	training's l2: 0.400667	valid_1's l2: 0.448176
# [150]	training's l2: 0.385299	valid_1's l2: 0.431893
# [200]	training's l2: 0.381211	valid_1's l2: 0.427861
# [250]	training's l2: 0.379352	valid_1's l2: 0.426312
# [300]	training's l2: 0.377996	valid_1's l2: 0.425484
# [350]	training's l2: 0.377069	valid_1's l2: 0.425082
# [400]	training's l2: 0.376287	valid_1's l2: 0.424838
# [450]	training's l2: 0.3757	valid_1's l2: 0.424586
# [500]	training's l2: 0.375159	valid_1's l2: 0.424476
# [550]	training's l2: 0.374633	valid_1's l2: 0.424316
# [600]	training's l2: 0.374133	valid_1's l2: 0.424166
# [650]	training's l2: 0.373675	valid_1's l2: 0.424078
# [700]	training's l2: 0.373236	valid_1's l2: 0.424004
# [750]	training's l2: 0.372837	valid_1's l2: 0.423939
# [800]	training's l2: 0.372423	valid_1's l2: 0.42388
# [850]	training's l2: 0.372016	valid_1's l2: 0.42383
# [900]	training's l2: 0.371647	valid_1's l2: 0.423838
# [950]	training's l2: 0.37127	valid_1's l2: 0.423774
# [1000]	training's l2: 0.37091	valid_1's l2: 0.423791
# Early stopping, best iteration is:
# [954]	training's l2: 0.371239	valid_1's l2: 0.42377
# mean_16_2017: 11650422.11
# mean_14_2017: 3459054.08
# median_16_2017: 1440191.50
# promo_15: 1241058.43
# mean_7_2017: 1070122.34
# promo_14_2017: 255818.68
# median_7_2017: 237918.82
# median_14_2017: 213805.32
# promo_1: 170472.65
# std_16_2017: 157041.69
# promo_8: 120894.59
# std_14_2017: 74592.11
# mean_3_2017: 60843.36
# promo_14: 52397.89
# promo_13: 50037.89
# promo_10: 42966.16
# std_7_2017: 40285.37
# promo_11: 37033.32
# std_3_2017: 30963.55
# median_3_2017: 30836.51
# promo_0: 23479.33
# promo_3: 22092.28
# promo_12: 19385.47
# promo_7: 11040.22
# promo_5: 9032.21
# promo_2: 6432.08
# promo_9: 6135.29
# promo_4: 4114.84
# promo_6: 2853.69
# Validation mse: 0.42600717367894936

# %%
print("Making submission...")
y_test = np.array(test_pred).transpose()
df_preds = pd.DataFrame(
    y_test, index=df_train.index,
    columns=pd.date_range("2017-08-16", periods=16)
).stack().to_frame("unit_sales")
df_preds.index.set_names(["store_nbr", "item_nbr", "date"], inplace=True)

submission = df_test[["id"]].join(df_preds, how="left").fillna(0)
submission["unit_sales"] = np.clip(np.expm1(submission["unit_sales"]), 0, 1000)
submission.to_csv('modified_weight_promo_1.csv', float_format='%.4f', index=None)
# Out:
# Making submission...
